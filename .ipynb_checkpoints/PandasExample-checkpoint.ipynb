# %%
import pandas as py
import numpy as np

# %%
lst = ["hai", "Hello", "My", "Name", "is", "Jenin"]

# %%
dataframe = py.DataFrame(lst)

# %%
dataframe
# Out:
#        0
# 0    hai
# 1  Hello
# 2     My
# 3   Name
# 4     is
# 5  Jenin

# %%
dict = {'Name':["jenin", "navendu", "abi", "goutham", "jithin"],
       'Age':[23,26,21,23,56],
       'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj','Angamaly'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd','Bsc']}

# %%
dictdata = py.DataFrame(dict)

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata[['Name','Address']]
# Out:
#       Name    Address
# 0    jenin      Delhi
# 1  navendu     Kanpur
# 2      abi  Allahabad
# 3  goutham    Kannauj
# 4   jithin   Angamaly

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
csvdata = py.read_csv('D:\\ML\\Data\\iris.csv', index_col='Species')

# %%
csvdata
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
first = csvdata.loc['Iris-setosa']

# %%
first
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa   1            5.1           3.5            1.4           0.2
# Iris-setosa   2            4.9           3.0            1.4           0.2
# Iris-setosa   3            4.7           3.2            1.3           0.2
# Iris-setosa   4            4.6           3.1            1.5           0.2
# Iris-setosa   5            5.0           3.6            1.4           0.2
# Iris-setosa   6            5.4           3.9            1.7           0.4
# Iris-setosa   7            4.6           3.4            1.4           0.3
# Iris-setosa   8            5.0           3.4            1.5           0.2
# Iris-setosa   9            4.4           2.9            1.4           0.2
# Iris-setosa  10            4.9           3.1            1.5           0.1
# Iris-setosa  11            5.4           3.7            1.5           0.2
# Iris-setosa  12            4.8           3.4            1.6           0.2
# ...

# %%
rows = csvdata.iloc[5]

# %%
rows
# Out:
# Id               6.0
# SepalLengthCm    5.4
# SepalWidthCm     3.9
# PetalLengthCm    1.7
# PetalWidthCm     0.4
# Name: Iris-setosa, dtype: float64

# %%
missingdata = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# %%
missingdata
# Out:
# {'First Score': [100, 90, nan, 95],
#  'Second Score': [30, 45, 56, nan],
#  'Third Score': [nan, 40, 80, 98]}

# %%
missingdataframe = py.DataFrame(missingdata)

# %%
missingdataframe
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
missingdataframe.isnull().sum()
# Out:
# First Score     1
# Second Score    1
# Third Score     1
# dtype: int64

# %%
missingdataframe.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
newdata = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# %%
ndata = py.DataFrame(newdata)

# %%
ndata
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
ndata.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
# creating a dataframe from a dictionary 
df = py.DataFrame(dict)

# %%
df
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
for i,j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %%
coloum = list(df)

# %%
coloum
# Out:
# ['name', 'degree', 'score']

# %%
for i in coloum:
    print(df[i][2])
# Out:
# sudhir
# M.Tech
# 80

# %%
static_value = 'Male'
df['occupation'] = static_value
print(df)
# Out:
#      name  degree  score occupation
# 0  aparna     MBA     90       Male
# 1  pankaj     BCA     40       Male
# 2  sudhir  M.Tech     80       Male
# 3   Geeku     MBA     98       Male

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata.drop(columns='Status')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 dictdata.drop(columns='Status')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
dictdata.insert(3, 'Status', ['youth' if age<=25 else 'Kelavan' for age in dictdata["Age"]])

# %%
dictdata
# Out:
#       Name  Age    Address   Status Qualification
# 0    jenin   23      Delhi    youth           Msc
# 1  navendu   26     Kanpur  Kelavan            MA
# 2      abi   21  Allahabad    youth           MCA
# 3  goutham   23    Kannauj    youth           Phd
# 4   jithin   56   Angamaly  Kelavan           Bsc

# %%
dictdata.drop(columns='Status')
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata
# Out:
#       Name  Age    Address   Status Qualification
# 0    jenin   23      Delhi    youth           Msc
# 1  navendu   26     Kanpur  Kelavan            MA
# 2      abi   21  Allahabad    youth           MCA
# 3  goutham   23    Kannauj    youth           Phd
# 4   jithin   56   Angamaly  Kelavan           Bsc

# %%
dictdata.drop(columns='Status', inplace=True)

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
dictdata[['Name','Status']]

# %%
ser = py.Series(dictdata['Status'])

# %%
ser

# %%
ser[:3]

# %%
ser1 = py.Series(np.linspace(1, 300, 5))
print(ser1)

# %%
dictdata

# %%
dictdata.describe()
# Out:
#             Age
# count   5.00000
# mean   29.80000
# std    14.75466
# min    21.00000
# 25%    23.00000
# 50%    23.00000
# 75%    26.00000
# max    56.00000

# %%
perc = [.20, .40, .60, .80]
include = ['object', 'float', 'int']
dictdata.describe(percentiles=perc, include=include)
# Out:
#          Name       Age Address Qualification
# count       5   5.00000       5             5
# unique      5       NaN       5             5
# top     jenin       NaN   Delhi           Msc
# freq        1       NaN       1             1
# mean      NaN  29.80000     NaN           NaN
# std       NaN  14.75466     NaN           NaN
# min       NaN  21.00000     NaN           NaN
# 20%       NaN  22.60000     NaN           NaN
# 40%       NaN  23.00000     NaN           NaN
# 50%       NaN  23.00000     NaN           NaN
# 60%       NaN  24.20000     NaN           NaN
# 80%       NaN  32.00000     NaN           NaN
# max       NaN  56.00000     NaN           NaN

# %%
dictdata['Name'].describe()
# Out:
# count         5
# unique        5
# top       jenin
# freq          1
# Name: Name, dtype: object

# %%
dictdata

# %%
dictdata[['Name','Age']].to_numpy()
# Out:
# array([['jenin', 23],
#        ['navendu', 26],
#        ['abi', 21],
#        ['goutham', 23],
#        ['jithin', 56]], dtype=object)

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
df = py.DataFrame(
     [[1, 2, 3],
     [4, 5, 6.5],
     [7, 8.5, 9],
     [10, 11, 12]],
    columns=['a', 'b', 'c'])
arr = df.to_numpy()

# %%
arr.dtype
# Out:
# dtype('float64')

# %%
index = ['city 1', 'city 2', 'city 3', 'city 4', 'city 5']
address = py.Series(dictdata['Address'])
address.index = index
address
# Out:
# city 1        Delhi
# city 2       Kanpur
# city 3    Allahabad
# city 4      Kannauj
# city 5     Angamaly
# Name: Address, dtype: object

# %%
address = address.to_numpy()

# %%
address
# Out:
# array(['Delhi', 'Kanpur', 'Allahabad', 'Kannauj', 'Angamaly'],
#       dtype=object)

# %%
sr = py.Series(['New York', 'Chicago', 'Toronto', 'Lisbon', 'Rio']) 
  
# Create the Index 
index_ = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5']  
  
# set the index 
sr.index = index_

# %%
sr
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# City 5         Rio
# dtype: object

# %%
d=sr.values

# %%
d
# Out:
# array(['New York', 'Chicago', 'Toronto', 'Lisbon', 'Rio'], dtype=object)

# %%
dictdata
# Out:
#       Name  Age    Address Qualification
# 0    jenin   23      Delhi           Msc
# 1  navendu   26     Kanpur            MA
# 2      abi   21  Allahabad           MCA
# 3  goutham   23    Kannauj           Phd
# 4   jithin   56   Angamaly           Bsc

# %%
csvdata = py.read_csv('D:\\ML\\Data\\iris.csv', index_col='Species')

# %%
csvdata
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
csvdata.loc['Iris-setosa':'Iris-virginica']
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       1            5.1           3.5            1.4           0.2
# Iris-setosa       2            4.9           3.0            1.4           0.2
# Iris-setosa       3            4.7           3.2            1.3           0.2
# Iris-setosa       4            4.6           3.1            1.5           0.2
# Iris-setosa       5            5.0           3.6            1.4           0.2
# ...             ...            ...           ...            ...           ...
# Iris-virginica  146            6.7           3.0            5.2           2.3
# Iris-virginica  147            6.3           2.5            5.0           1.9
# Iris-virginica  148            6.5           3.0            5.2           2.0
# Iris-virginica  149            6.2           3.4            5.4           2.3
# Iris-virginica  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
type(csvdata)
# Out:
# pandas.core.frame.DataFrame

# %%
    csvdata = py.read_csv('D:\\ML\\Data\\iris.csv')

# %%
csvdata.loc[3]
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
csvdata.iloc[3]
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
row1 = csvdata.iloc[3:6]
row2 = csvdata.iloc[[3,4,5]]

# %%
row1 == row2
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 3  True           True          True           True          True     True
# 4  True           True          True           True          True     True
# 5  True           True          True           True          True     True

# %%
example = py.read_csv('D:\\ML\\Data\\nba-2.csv', index_col='Name')

# %%
example
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
example.loc[['Amir Johnson', 'Terry Rozier']]
# Out:
#                         Team  Number Position   Age Height  Weight  \
# Name
# Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#                  College      Salary
# Name
# Amir Johnson         NaN  12000000.0
# Terry Rozier  Louisville   1824360.0

# %%
example[['Age','College','Salary']]
# Out:
#                 Age            College     Salary
# Name
# Avery Bradley  25.0              Texas  7730337.0
# Jae Crowder    25.0          Marquette  6796117.0
# John Holland   27.0  Boston University        NaN
# R.J. Hunter    22.0      Georgia State  1148640.0
# Jonas Jerebko  29.0                NaN  5000000.0
# ...             ...                ...        ...
# Shelvin Mack   26.0             Butler  2433333.0
# Raul Neto      24.0                NaN   900000.0
# Tibor Pleiss   26.0                NaN  2900000.0
# Jeff Withey    26.0             Kansas   947276.0
# NaN             NaN                NaN        NaN
#
# [458 rows x 3 columns]

# %%
example[['Age','College','Salary']].loc[['Amir Johnson', 'Terry Rozier']]
# Out:
#                Age     College      Salary
# Name
# Amir Johnson  29.0         NaN  12000000.0
# Terry Rozier  22.0  Louisville   1824360.0

# %%
example.loc[['Amir Johnson', 'Terry Rozier','John Holland']]
# Out:
#                         Team  Number Position   Age Height  Weight  \
# Name
# Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#                         College      Salary
# Name
# Amir Johnson                NaN  12000000.0
# Terry Rozier         Louisville   1824360.0
# John Holland  Boston University         NaN

# %%
example[['Age','Height','Salary']]
# Out:
#                 Age Height     Salary
# Name
# Avery Bradley  25.0    6-2  7730337.0
# Jae Crowder    25.0    6-6  6796117.0
# John Holland   27.0    6-5        NaN
# R.J. Hunter    22.0    6-5  1148640.0
# Jonas Jerebko  29.0   6-10  5000000.0
# ...             ...    ...        ...
# Shelvin Mack   26.0    6-3  2433333.0
# Raul Neto      24.0    6-1   900000.0
# Tibor Pleiss   26.0    7-3  2900000.0
# Jeff Withey    26.0    7-0   947276.0
# NaN             NaN    NaN        NaN
#
# [458 rows x 3 columns]

# %%
example
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
example['Age'] == 25.0
# Out:
# Name
# Avery Bradley     True
# Jae Crowder       True
# John Holland     False
# R.J. Hunter      False
# Jonas Jerebko    False
#                  ...
# Shelvin Mack     False
# Raul Neto        False
# Tibor Pleiss     False
# Jeff Withey      False
# NaN              False
# Name: Age, Length: 458, dtype: bool

# %%
example['Age'] > 25.0
# Out:
# Name
# Avery Bradley    False
# Jae Crowder      False
# John Holland      True
# R.J. Hunter      False
# Jonas Jerebko     True
#                  ...
# Shelvin Mack      True
# Raul Neto        False
# Tibor Pleiss      True
# Jeff Withey       True
# NaN              False
# Name: Age, Length: 458, dtype: bool

# %%
randomnum = py.DataFrame(np.random.randn(10,5),columns=['A','B','C','D','E'])

# %%
randomnum
# Out:
#           A         B         C         D         E
# 0  1.830435 -1.009854 -0.126308  0.267233 -0.022889
# 1  0.095537  0.742982 -0.289697  1.148480  0.522132
# 2 -0.313378 -0.166750  0.114463  0.517933  1.427868
# 3  0.871406  0.061822 -0.938766  1.138289 -0.247482
# 4 -2.280417 -0.405867 -0.169245  0.090810  0.726292
# 5 -0.356543  0.955961 -0.464081 -0.004162 -0.178623
# 6 -0.201778 -0.845697  0.423985  0.228672 -0.843148
# 7 -0.574202 -0.103942  0.293917 -1.280698  1.382117
# 8 -0.383652  0.632254 -0.053941  0.303773  2.008470
# 9  0.230319 -0.434135 -0.989453 -0.572217  0.392229

# %%
randomnum.iloc[7]
# Out:
# A   -0.574202
# B   -0.103942
# C    0.293917
# D   -1.280698
# E    1.382117
# Name: 7, dtype: float64

# %%
newexample = py.DataFrame( {'Name': ['Pandas', 'Geeks', 'for', 'Geeks'],
        'Height': [1, 2, 3, 4],
        'Qualification': ['A', 'B', 'C', 'D']})

# %%
newexample
# Out:
#      Name  Height Qualification
# 0  Pandas       1             A
# 1   Geeks       2             B
# 2     for       3             C
# 3   Geeks       4             D

# %%
newexample.assign(address=['NewYork','Angamaly','Kalady','Malayattoor'])
# Out:
#      Name  Height Qualification      address
# 0  Pandas       1             A      NewYork
# 1   Geeks       2             B     Angamaly
# 2     for       3             C       Kalady
# 3   Geeks       4             D  Malayattoor

# %%
weight = {'Pandas':'27','Geeks':'56','for':'85','Geeks':'95'}

# %%
newexample['Weight'] = newexample['Name'].map(weight)

# %%
newexample
# Out:
#      Name  Height Qualification Weight
# 0  Pandas       1             A     27
# 1   Geeks       2             B     95
# 2     for       3             C     85
# 3   Geeks       4             D     95

# %%
newexample.assign(address=['NewYork','Angamaly','Kalady','Malayattoor'])
# Out:
#      Name  Height Qualification Weight      address
# 0  Pandas       1             A     27      NewYork
# 1   Geeks       2             B     95     Angamaly
# 2     for       3             C     85       Kalady
# 3   Geeks       4             D     95  Malayattoor

# %%
newexample
# Out:
#      Name  Height Qualification Weight
# 0  Pandas       1             A     27
# 1   Geeks       2             B     95
# 2     for       3             C     85
# 3   Geeks       4             D     95

# %%
newexample.assign(address=['NewYork','Angamaly','Kalady','Malayattoor'], inplace=True)
# Out:
#      Name  Height Qualification Weight      address  inplace
# 0  Pandas       1             A     27      NewYork     True
# 1   Geeks       2             B     95     Angamaly     True
# 2     for       3             C     85       Kalady     True
# 3   Geeks       4             D     95  Malayattoor     True

# %%
newexample
# Out:
#      Name  Height Qualification Weight
# 0  Pandas       1             A     27
# 1   Geeks       2             B     95
# 2     for       3             C     85
# 3   Geeks       4             D     95

# %%
newexample['Address'] = ['NewYork','Angamaly','Kalady','Malayattoor']

# %%
newexample
# Out:
#      Name  Height Qualification Weight      Address
# 0  Pandas       1             A     27      NewYork
# 1   Geeks       2             B     95     Angamaly
# 2     for       3             C     85       Kalady
# 3   Geeks       4             D     95  Malayattoor

# %%
newvalue = {'Pandas':'27','Geeks':'56','Geeks':'95'}

# %%
newexample['Weight'] = newexample['Name'].map(newvalue)

# %%
newexample
# Out:
#      Name  Height Qualification Weight      Address NewValue
# 0  Pandas       1             A     27      NewYork       27
# 1   Geeks       2             B     95     Angamaly       95
# 2     for       3             C    NaN       Kalady       85
# 3   Geeks       4             D     95  Malayattoor       95

# %%
newexample['NewValue'] = newexample['Name'].map(newvalue)

# %%
newexample
# Out:
#      Name  Height Qualification Weight      Address NewValue
# 0  Pandas       1             A     27      NewYork       27
# 1   Geeks       2             B     95     Angamaly       95
# 2     for       3             C    NaN       Kalady      NaN
# 3   Geeks       4             D     95  Malayattoor       95

# %%
newexample.fillna(0)
# Out:
#      Name  Height Qualification Weight      Address NewValue
# 0  Pandas       1             A     27      NewYork       27
# 1   Geeks       2             B     95     Angamaly       95
# 2     for       3             C      0       Kalady        0
# 3   Geeks       4             D     95  Malayattoor       95

# %%
newexample1 = newexample.to_numpy()

# %%
newexample1
# Out:
# array([['Pandas', 1, 'A', '27', 'NewYork', '27'],
#        ['Geeks', 2, 'B', '95', 'Angamaly', '95'],
#        ['for', 3, 'C', nan, 'Kalady', nan],
#        ['Geeks', 4, 'D', '95', 'Malayattoor', '95']], dtype=object)
